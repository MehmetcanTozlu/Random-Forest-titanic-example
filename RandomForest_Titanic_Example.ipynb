# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Cabin Column'unu kaldirdik

# %%
df = df.drop('Cabin', axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
age = df.iloc[:, 5:6].values

# %%
age
# Out:
# array([[22.  ],
#        [38.  ],
#        [26.  ],
#        [35.  ],
#        [35.  ],
#        [  nan],
#        [54.  ],
#        [ 2.  ],
#        [27.  ],
#        [14.  ],
#        [ 4.  ],
#        [58.  ],
#        [20.  ],
#        [39.  ],
#        [14.  ],
#        [55.  ],
#        [ 2.  ],
#        [  nan],
#        [31.  ],
#        [  nan],
#        [35.  ],
#        [34.  ],
#        [15.  ],
#        [28.  ],
#        [ 8.  ],
#        [38.  ],
#        [  nan],
#        [19.  ],
#        [  nan],
#        [  nan],
#        [40.  ],
#        [  nan],
#        [  nan],
#        [66.  ],
#        [28.  ],
#        [42.  ],
#        [  nan],
#        [21.  ],
#        [18.  ],
#        [14.  ],
#        [40.  ],
#        [27.  ],
#        [  nan],
#        [ 3.  ],
#        [19.  ],
#        [  nan],
#        [  nan],
#        [  nan],
#        [  nan],
#        [18.  ],
#        [ 7.  ],
#        [21.  ],
#        [49.  ],
#        [29.  ],
#        [65.  ],
# ...

# %%
age = imputer.fit_transform(age)

# %%
a = list(map(lambda i: int(i), age))

# %%
a
# Out:
# [22,
#  38,
#  26,
#  35,
#  35,
#  29,
#  54,
#  2,
#  27,
#  14,
#  4,
#  58,
#  20,
#  39,
#  14,
#  55,
#  2,
#  29,
#  31,
#  29,
#  35,
#  34,
#  15,
#  28,
#  8,
#  38,
#  29,
#  19,
#  29,
#  29,
#  40,
#  29,
#  29,
#  66,
#  28,
#  42,
#  29,
#  21,
#  18,
#  14,
#  40,
#  27,
#  29,
#  3,
#  19,
#  29,
#  29,
#  29,
#  29,
#  18,
#  7,
#  21,
#  49,
#  29,
#  65,
#  29,
#  21,
#  28,
#  5,
#  11,
#  22,
#  38,
#  45,
#  4,
#  29,
#  29,
#  29,
#  19,
#  17,
#  26,
#  32,
#  16,
#  21,
#  26,
#  32,
#  25,
#  29,
#  29,
#  0,
#  30,
#  22,
#  29,
#  29,
#  28,
#  17,
#  33,
#  16,
#  29,
#  23,
#  24,
#  29,
#  20,
#  46,
#  26,
#  59,
#  29,
#  71,
#  23,
#  34,
#  34,
#  28,
#  29,
#  21,
#  33,
#  37,
#  28,
#  21,
#  29,
#  38,
#  29,
#  47,
#  14,
#  22,
#  20,
#  17,
#  21,
#  70,
#  29,
#  24,
#  2,
#  21,
#  29,
#  32,
#  32,
#  54,
#  12,
#  29,
#  24,
#  29,
#  45,
#  33,
#  20,
#  47,
#  29,
#  25,
#  23,
#  19,
#  37,
#  16,
#  24,
#  29,
#  22,
#  24,
#  19,
# ...

# %%
age = a

# %% [markdown]
# ### Age Column'unda ki NaN verileri Column'un ortalamasi ile degistirdik

# %%
age
# Out:
# [22,
#  38,
#  26,
#  35,
#  35,
#  29,
#  54,
#  2,
#  27,
#  14,
#  4,
#  58,
#  20,
#  39,
#  14,
#  55,
#  2,
#  29,
#  31,
#  29,
#  35,
#  34,
#  15,
#  28,
#  8,
#  38,
#  29,
#  19,
#  29,
#  29,
#  40,
#  29,
#  29,
#  66,
#  28,
#  42,
#  29,
#  21,
#  18,
#  14,
#  40,
#  27,
#  29,
#  3,
#  19,
#  29,
#  29,
#  29,
#  29,
#  18,
#  7,
#  21,
#  49,
#  29,
#  65,
#  29,
#  21,
#  28,
#  5,
#  11,
#  22,
#  38,
#  45,
#  4,
#  29,
#  29,
#  29,
#  19,
#  17,
#  26,
#  32,
#  16,
#  21,
#  26,
#  32,
#  25,
#  29,
#  29,
#  0,
#  30,
#  22,
#  29,
#  29,
#  28,
#  17,
#  33,
#  16,
#  29,
#  23,
#  24,
#  29,
#  20,
#  46,
#  26,
#  59,
#  29,
#  71,
#  23,
#  34,
#  34,
#  28,
#  29,
#  21,
#  33,
#  37,
#  28,
#  21,
#  29,
#  38,
#  29,
#  47,
#  14,
#  22,
#  20,
#  17,
#  21,
#  70,
#  29,
#  24,
#  2,
#  21,
#  29,
#  32,
#  32,
#  54,
#  12,
#  29,
#  24,
#  29,
#  45,
#  33,
#  20,
#  47,
#  29,
#  25,
#  23,
#  19,
#  37,
#  16,
#  24,
#  29,
#  22,
#  24,
#  19,
# ...

# %%
df.iloc[:, 5:6] = age

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.iloc[:, -1] = df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df = df.drop('Name', axis=1)

# %% [markdown]
# ### Ticket Column'unda 210 tane veri tekrar ediyormus

# %%
df[['Ticket']].duplicated().sum()
# Out:
# 210

# %% [markdown]
# ### Sex Column'unu categoric'den numeric cevirelim

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df.iloc[:, 3:4] = le.fit_transform(df.iloc[:, 3:4])
# Out:
# C:\python39\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1   22      1      0         A/5 21171
# 1              2         1       1    0   38      1      0          PC 17599
# 2              3         1       3    0   26      0      0  STON/O2. 3101282
# 3              4         1       1    0   35      1      0            113803
# 4              5         0       3    1   35      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    1   27      0      0            211536
# 887          888         1       1    0   19      0      0            112053
# 888          889         0       3    0   29      1      2        W./C. 6607
# 889          890         1       1    1   26      0      0            111369
# 890          891         0       3    1   32      0      0            370376
#
#         Fare  Embarked
# ...

# %% [markdown]
# #### male = 1, female = 0

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.544332
# std     257.353842    0.486592    0.836071    0.477990   13.013778
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    1.000000   29.000000
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208  446.000000
# std      1.102743    0.806057   49.693429  257.353842
# min      0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    7.910400  223.500000
# ...

# %%
plt.hist(df.iloc[:, 4:5])
plt.xlabel('Yas')
plt.ylabel('Hayatta Kalanlarin Sayisi')
plt.show()

# %%
plt.title('Bilet Paralarina Gore Hayatta Kalma')
sns.stripplot(x='Survived', y='Fare', data=df)
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1   22      1      0         A/5 21171
# 1              2         1       1    0   38      1      0          PC 17599
# 2              3         1       3    0   26      0      0  STON/O2. 3101282
# 3              4         1       1    0   35      1      0            113803
# 4              5         0       3    1   35      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    1   27      0      0            211536
# 887          888         1       1    0   19      0      0            112053
# 888          889         0       3    0   29      1      2        W./C. 6607
# 889          890         1       1    1   26      0      0            111369
# 890          891         0       3    1   32      0      0            370376
#
#         Fare  Embarked
# ...

# %%
independent = df[['Sex', 'Age']]

# %%
independent
# Out:
#      Sex  Age
# 0      1   22
# 1      0   38
# 2      0   26
# 3      0   35
# 4      1   35
# ..   ...  ...
# 886    1   27
# 887    0   19
# 888    0   29
# 889    1   26
# 890    1   32
#
# [891 rows x 2 columns]

# %%
dependent = df.iloc[:, 1:2] # Survived

# %%
dependent
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.33, random_state=0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor(n_estimators=20, random_state=0)

# %%
rf_reg.fit(X_train, y_train)
# Out:
# C:\Users\mehmet\AppData\Local\Temp\ipykernel_9288\3901435218.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(X_train, y_train)
# RandomForestRegressor(n_estimators=20, random_state=0)

# %%
rf_reg.predict([[1, 20]])
# Out:
# C:\python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([0.14209664])
